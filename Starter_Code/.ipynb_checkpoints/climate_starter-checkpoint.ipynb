# %%
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd
import datetime as dt

# %% [markdown]
# # Reflect Tables into SQLAlchemy ORM

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func ,inspect

# %%
# create engine to hawaii.sqlite
engine = create_engine("sqlite:///Resources/hawaii.sqlite")

# %%
# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect= True)

# %%
# View all of the classes that automap found
Base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %% [markdown]
# # Exploratory Precipitation Analysis

# %%
# Find the most recent date in the data set.

#find column names of measurement table
insp=inspect(engine)
columns_measure= insp.get_columns("measurement")
for column in columns_measure:
    print(column["name"], column["type"])
# Out:
# id INTEGER
# station TEXT
# date TEXT
# prcp FLOAT
# tobs FLOAT

# %%
#find column names of station table
insp=inspect(engine)
columns_station= insp.get_columns("station")
for column in columns_station:
    print(column["name"], column["type"])
# Out:
# id INTEGER
# station TEXT
# name TEXT
# latitude FLOAT
# longitude FLOAT
# elevation FLOAT

# %%
# Find the most recent date in the data set.
recent_date_measure= session.query(Measurement.date).\
    order_by(Measurement.date.desc()).first()


print(recent_date_measure)
# Out:
# ('2017-08-23',)

# %%
# Design a query to retrieve the last 12 months of precipitation data and plot the results. 
# Starting from the most recent data point in the database. 

# Calculate the date one year from the last date in data set.
another_date = dt.date(2017,8,23) - dt.timedelta(days=365)
print(another_date)

# Perform a query to retrieve the data and precipitation scores
data = session.query(Measurement.date, Measurement.prcp).filter(Measurement.date >= another_date).all()
for record in data:
    print(record)

# Save the query results as a Pandas DataFrame and set the index to the date column
measurement_df = pd.DataFrame(data, columns = ["date", "precipitation"])
measurement_df.set_index("date", inplace=True)
# Out:
# 2016-08-23
# ('2016-08-23', 0.0)
# ('2016-08-24', 2.0)
# ('2016-08-25', 2.0)
# ('2016-08-26', 0.0)
# ('2016-08-27', 0.0)
# ('2016-08-28', 0.3)
# ('2016-08-29', 0.0)
# ('2016-08-30', 0.0)
# ('2016-08-31', 3.3)
# ('2016-09-01', 0.0)
# ('2016-09-02', 0.0)
# ('2016-09-03', 0.0)
# ('2016-09-04', 0.8)
# ('2016-09-05', None)
# ('2016-09-06', None)
# ('2016-09-07', 1.3)
# ('2016-09-08', 0.0)
# ('2016-09-09', 0.8)
# ('2016-09-10', 0.0)
# ('2016-09-11', 1.3)
# ('2016-09-12', 0.0)
# ('2016-09-13', 0.5)
# ('2016-09-14', 33.5)
# ('2016-09-15', 10.7)
# ('2016-09-16', 1.5)
# ('2016-09-17', 1.3)
# ('2016-09-18', 0.0)
# ('2016-09-19', 0.0)
# ('2016-09-20', 0.0)
# ('2016-09-21', 0.0)
# ('2016-09-22', 0.5)
# ('2016-09-23', 0.0)
# ('2016-09-24', 0.0)
# ('2016-09-25', 0.0)
# ('2016-09-26', 1.5)
# ('2016-09-27', 0.5)
# ('2016-09-28', 0.0)
# ('2016-09-29', 0.0)
# ('2016-09-30', 0.0)
# ('2016-10-01', 0.0)
# ('2016-10-02', 0.0)
# ('2016-10-03', 0.0)
# ('2016-10-04', 0.0)
# ('2016-10-05', 0.0)
# ...

# %%
# Sort the dataframe by date
measurement_df =measurement_df.sort_values(["date"])
measurement_df.head(100)
# Out:
#             precipitation
# date
# 2016-08-23            0.0
# 2016-08-23            NaN
# 2016-08-23           45.5
# 2016-08-23            1.3
# 2016-08-23            3.8
# ...                   ...
# 2016-09-07            1.3
# 2016-09-07            2.8
# 2016-09-07            2.5
# 2016-09-07           34.3
# 2016-09-07            5.8
#
# [100 rows x 1 columns]

# %%
# Use Pandas Plotting with Matplotlib to plot the data
fig = measurement_df.plot(rot=45, title = "precipitation", xlabel='Date', ylabel = "mm", figsize=(9,6))

plt.tight_layout()
plt.show()

# %%
# Use Pandas to calcualte the summary statistics for the precipitation data
statistics = measurement_df["precipitation"].describe()
statistics_df = pd.DataFrame(statistics)
statistics_df
# Out:
#        precipitation
# count    2021.000000
# mean        4.505888
# std        11.713487
# min         0.000000
# 25%         0.000000
# 50%         0.500000
# 75%         3.300000
# max       170.200000

# %% [markdown]
# # Exploratory Station Analysis

# %%
# Design a query to calculate the total number stations in the dataset
session.query(Station).group_by(Station.station).count()
# Out:
# 9

# %%
# Design a query to find the most active stations (i.e. what stations have the most rows?)
# List the stations and the counts in descending order.
session.query(Measurement.station, func.count(Measurement.date)).group_by(Measurement.station).\
    order_by(func.count(Measurement.date).desc()).all()
# Out:
# [('USC00519281', 2772),
#  ('USC00519397', 2724),
#  ('USC00513117', 2709),
#  ('USC00519523', 2669),
#  ('USC00516128', 2612),
#  ('USC00514830', 2202),
#  ('USC00511918', 1979),
#  ('USC00517948', 1372),
#  ('USC00518838', 511)]

# %%
# Most active station id
most_active_station=session.query(Measurement.station).group_by(Measurement.station).\
    order_by(func.count(Measurement.date).desc()).first()
most_active= most_active_station[0]
most_active
# Out:
# 'USC00519281'

# %%
# Using the most active station id from the previous query, calculate the lowest, highest, and average temperature

session.query(Measurement.station, func.min(Measurement.tobs), func.max(Measurement.tobs), func.avg(Measurement.tobs)).\
    filter(Measurement.station==most_active).all()
# Out:
# [('USC00519281', 12.2, 29.4, 22.03582251082252)]

# %%
# Using the most active station id
# Query the last 12 months of temperature observation data for this station 
sel = [Measurement.date, 
       Measurement.tobs]
station_temps = session.query(*sel).\
        filter(func.strftime(Measurement.date) >= another_date, Measurement.station == 'USC00519281').\
        group_by(Measurement.date).\
        order_by(Measurement.date).all()
station_temps
# Create a dataframe
station_temps_df = pd.DataFrame(station_temps, columns=['Measurement Date', 'Temperature'])
station_temps_df.head()
# Out:
#   Measurement Date  Temperature
# 0       2016-08-23         25.0
# 1       2016-08-24         25.0
# 2       2016-08-25         26.7
# 3       2016-08-26         26.7
# 4       2016-08-27         23.9

# %%
# plot the results as a histogram
plt.hist(station_temps_df['Temperature'],bins=12, density=False, label="TOBS")
plt.xlabel("Temperature (Fahrenheit)")
plt.ylabel("Frequency")
plt.legend()
plt.title("Temperature Observations at USC00519281")
plt.figsize=(10,7)
plt.savefig('Annual_Temps_USC00519281.png',bbox_inches='tight')
plt.show()

# %% [markdown]
# # Close session

# %%
# Close Session
session.close()
